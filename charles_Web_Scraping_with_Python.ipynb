# %% [markdown]
# **Background Information**
#
# Together with a team of startup entrepreneurs, you decide to work on an idea that could change the way people search for jobs. You decide that job scraping could be the next big thing as there are actively many people looking for jobs in the country, in this case, Kenya.
# **Problem Statement**
#
# The problem is that there are many job listings which can not get visits for the target job seekers. While working in a team, your task as a data scientist for this project is to scrape for job titles and links and then put them in a single table that can be used by your team members to further build a job aggregator. You will be required to scrape for data from the following three technology webpages:
#
# ● PigiaMe: https://www.pigiame.co.ke/it-software-jobs
#
# ● MyJobMag: https://www.myjobmag.co.ke/jobs-by-field/information-technology
#
# ● KenyaJob: https://www.kenyajob.com/job-vacancies-search-kenya?f%5B0%5D=im_field_offr e_secteur%3A133

# %% [markdown]
# ## <font color='#2F4F4F'>Prerequisites</font>

# %%
# We first import the required libraries
# ---
#
import pandas as pd             # library for data manupation
import requests                 # library for fetching a web page 
from bs4 import BeautifulSoup   # library for extrating contents from a webpage 
from urllib3.exceptions import InsecureRequestWarning
from urllib3 import disable_warnings

disable_warnings(InsecureRequestWarning)

# %% [markdown]
# ## <font color='#2F4F4F'>Step 1: Obtaining our Data</font>

# %%
# PigiaMe: https://www.pigiame.co.ke/it-software-jobs
# ---
#
pigia_me = requests.get('https://www.pigiame.co.ke/it-software-jobs')
pigia_me
# Out:
# <Response [200]>

# %%
# MyJobMag: https://www.myjobmag.co.ke/jobs-by-field/information-technology
# ---
#
myjob_mag = requests.get('https://www.myjobmag.co.ke/jobs-by-field/information-technology')
myjob_mag
# Out:
# <Response [200]>

# %%
# KenyanJob: https://www.kenyajob.com/job-vacancies-search-kenya?f%5B0%5D=im_field_offre_secteur%3A133
# ---
kenyan_job = requests.get('https://www.kenyajob.com/job-vacancies-search-kenya?f%5B0%5D=im_field_offre_secteur%3A133')
kenyan_job
# Out:
# <Response [200]>

# %% [markdown]
# ## <font color='#2F4F4F'>Step 2: Parsing</font>

# %%
# Parsing our document: pigia_me
# ---
#
pigia_me_soup= BeautifulSoup(pigia_me.text, "html.parser")

# %%
# Parsing our document: my_job_mag
# ---
#  
myjob_mag_soup = BeautifulSoup(myjob_mag.text,"html.parser")

# %%
# Parsing our document: kenyan_job
# ---
kenyan_job_soup= BeautifulSoup(kenyan_job.text, "html.parser")

# %% [markdown]
# ## <font color='#2F4F4F'>Step 3: Extracting Required Elements</font>

# %%
# Each job is enclosed in 'div' class 'listings-cards__list-item'
pigia_me_job =  pigia_me_soup.find_all('div', class_= 'listings-cards__list-item')

# 1. Extracting job titles and links: pigia me
# ---

# # 1. Extracting job titles
#job_title_pigia_me  =  pigiame_job.find('div', class_='listing-card__header__title').get_text().replace('\n', '')


#Extract links

# links are in href of class 'listing-card listing-card--tab listing-card--has-content listing-card--highlight-placeholder'
#link_pigia_me = pigiame_job.find('div', class_='listing-card listing-card--tab listing-card--has-content listing-card--highlight-placeholder').a['href']


#create a list for link and title
pigia_me_link_title = []
pigia_me_link_url = []

# loop in through the pigiame website and colleact the link and title 

for p in pigia_me_job:
    # getting the title and links
    job_title_pigia_me  =  p.find('div', class_='listing-card__header__title').get_text().replace('\n', '')
    link_pigia_me = p.find('div', class_='listing-card listing-card--tab listing-card--has-content listing-card--highlight-placeholder').a['href']

    #appending the title and links to the list
    # Then appending the text to our link_content list
    pigia_me_link_title.append(job_title_pigia_me)
      # Then appending the text to our link_url list
    pigia_me_link_url.append(link_pigia_me)
    
print(pigia_me_link_title)
['Bioinformatic and Software Developer', 'IT Sales - Cybersecurity & Cloud', 'Executive, Support & Services', 'Data Engineer', 'Software Development Trainer', 'Oracle Database Administrator', 'UI/UX & Frontend Developer – Limuru, Kenya', 'IT Sales - Cybersecurity & Cloud', 'Wordpress and Shopify Web Designer', 'Entry level Software Developer']
# 2. Extracting job titles: myjob_mag
# ---
# 
#jobtitle_myjob = soup_myjob.find('div', {'class':'listing-card__header__title'})[2].get_text()

# Extracting job titles
#Jobtilte is under <li class="job-list-li">
#<ul>
#<li class="job-logo">
#<a href="/jobs-at/cannon-general-insurance-k-ltd"><img src="/company_logo/86/61466Cannon General Insurance (K) Ltd.png" alt="Cannon General Insurance (K) Ltd logo" width="100%" height="auto" title="Cannon General Insurance (K) Ltd logo"></a>
#</li>
#<li class="job-info">
#<ul>
#<li class="mag-b">
#<h2><a href="/job/systems-developer-cannon-general-insurance-k-ltd">Systems Developer at Cannon General Insurance (K) Ltd</a></h2>
#</li>
#the job title and job link can be derived from 'li', class_ = 'mag-b'

myjob = myjob_mag_soup.find_all('li', class_ ='mag-b')

#create a list for link and title
myjob_link_title = []
myjob_link_url = []


#Extracting my job links and title

for link in myjob :
    myjob_link = 'https://www.myjobmag.co.ke' + link.find('h2').a['href']
    myjob_title = link.find('h2').a.text
    
     # Then appending the text to our link_content list
    myjob_link_title.append(myjob_title)

    # Then appending the text to our link_url list
    myjob_link_url.append(myjob_link)
    
    print(myjob_link_url)
# 3. Extracting job titles: kenya_job
# ---
#
# Each job is enclosed in 'div' class 'job-description-wrapper'
kenyanjob_job =  kenyan_job_soup.find_all('div', class_= 'job-description-wrapper')

# 1. Extracting job titles and links: 
# ---

# # 1. Extracting job titles . Titles are in calss 'col-lg-5 col-md-5 col-sm-5 col-xs-12 job-title'.h5.a.text

#kenyanjob_jobtitle  = kenyanjob_job.find('div', class_='col-lg-5 col-md-5 col-sm-5 col-xs-12 job-title').h5.a.text

#Extract links

# links are in calss 'col-lg-5 col-md-5 col-sm-5 col-xs-12 job-title'.h5.a['href']

#kenyanjob_joblink  = 'https://www.kenyajob.com' + kenyanjob_job.find('div', class_='col-lg-5 col-md-5 col-sm-5 col-xs-12 job-title').h5.a['href']


#create a list for link and title
kenyajob_link_title = []
kenyajob_link_url = []
# loop in through the pigiame website and colleact the link and title 

for k in kenyanjob_job :
    # getting the title and links
    
    kenyanjob_jobtitle  = k.find('div', class_='col-lg-5 col-md-5 col-sm-5 col-xs-12 job-title').h5.a.text
    kenyanjob_joblink  = 'https://www.kenyajob.com' + k.find('div', class_='col-lg-5 col-md-5 col-sm-5 col-xs-12 job-title').h5.a['href']

    #appending the title and links to the list
    # Then appending the text to our link_content list
    kenyajob_link_title.append(kenyanjob_jobtitle)

    # Then appending the text to our link_url list
    kenyajob_link_url.append(kenyanjob_joblink)
    
print(kenyajob_link_title)
# Out:
# ['VP, Data at Flutterwave', 'Process Engineer at DryGro', 'Analyst,MLU 3 at Church of Jesus Christ of Latter-day Saints', 'MEAN Stack Developer-MongoDB, AngularJS, and Node.js', 'Process Analyst at I&M Bank', 'ICT Support Technician at KCA University', 'Director, Data Products, Community Pass at MasterCard', 'Market Development Analyst', 'IT Officer - Systems', 'Engineering Lead']
# ['https://www.myjobmag.co.ke/job/information-technology-it-assistant-kakuzi-plc']
# ['https://www.myjobmag.co.ke/job/information-technology-it-assistant-kakuzi-plc', 'https://www.myjobmag.co.ke/job/python-software-engineer-ubuntu-hardware-certification-team-canonical-3']
# ['https://www.myjobmag.co.ke/job/information-technology-it-assistant-kakuzi-plc', 'https://www.myjobmag.co.ke/job/python-software-engineer-ubuntu-hardware-certification-team-canonical-3', 'https://www.myjobmag.co.ke/job/ict-intern-spear-the-science-for-africa-foundation']
# ['https://www.myjobmag.co.ke/job/information-technology-it-assistant-kakuzi-plc', 'https://www.myjobmag.co.ke/job/python-software-engineer-ubuntu-hardware-certification-team-canonical-3', 'https://www.myjobmag.co.ke/job/ict-intern-spear-the-science-for-africa-foundation', 'https://www.myjobmag.co.ke/job/ict-officer-i-tana-river-county']
# ['https://www.myjobmag.co.ke/job/information-technology-it-assistant-kakuzi-plc', 'https://www.myjobmag.co.ke/job/python-software-engineer-ubuntu-hardware-certification-team-canonical-3', 'https://www.myjobmag.co.ke/job/ict-intern-spear-the-science-for-africa-foundation', 'https://www.myjobmag.co.ke/job/ict-officer-i-tana-river-county', 'https://www.myjobmag.co.ke/job/software-engineer-data-infrastructure-opensearch-elastic-search-canonical-1']
# ['https://www.myjobmag.co.ke/job/information-technology-it-assistant-kakuzi-plc', 'https://www.myjobmag.co.ke/job/python-software-engineer-ubuntu-hardware-certification-team-canonical-3', 'https://www.myjobmag.co.ke/job/ict-intern-spear-the-science-for-africa-foundation', 'https://www.myjobmag.co.ke/job/ict-officer-i-tana-river-county', 'https://www.myjobmag.co.ke/job/software-engineer-data-infrastructure-opensearch-elastic-search-canonical-1', 'https://www.myjobmag.co.ke/job/senior-agile-program-manager-payment-methods-cellulant-corporation']
# ['https://www.myjobmag.co.ke/job/information-technology-it-assistant-kakuzi-plc', 'https://www.myjobmag.co.ke/job/python-software-engineer-ubuntu-hardware-certification-team-canonical-3', 'https://www.myjobmag.co.ke/job/ict-intern-spear-the-science-for-africa-foundation', 'https://www.myjobmag.co.ke/job/ict-officer-i-tana-river-county', 'https://www.myjobmag.co.ke/job/software-engineer-data-infrastructure-opensearch-elastic-search-canonical-1', 'https://www.myjobmag.co.ke/job/senior-agile-program-manager-payment-methods-cellulant-corporation', 'https://www.myjobmag.co.ke/job/consultant-global-hiv-drug-resistance-hivdr-database-world-health-organization']
# ['https://www.myjobmag.co.ke/job/information-technology-it-assistant-kakuzi-plc', 'https://www.myjobmag.co.ke/job/python-software-engineer-ubuntu-hardware-certification-team-canonical-3', 'https://www.myjobmag.co.ke/job/ict-intern-spear-the-science-for-africa-foundation', 'https://www.myjobmag.co.ke/job/ict-officer-i-tana-river-county', 'https://www.myjobmag.co.ke/job/software-engineer-data-infrastructure-opensearch-elastic-search-canonical-1', 'https://www.myjobmag.co.ke/job/senior-agile-program-manager-payment-methods-cellulant-corporation', 'https://www.myjobmag.co.ke/job/consultant-global-hiv-drug-resistance-hivdr-database-world-health-organization', 'https://www.myjobmag.co.ke/job/vas-support-engineer-safaricom-kenya']
# ['https://www.myjobmag.co.ke/job/information-technology-it-assistant-kakuzi-plc', 'https://www.myjobmag.co.ke/job/python-software-engineer-ubuntu-hardware-certification-team-canonical-3', 'https://www.myjobmag.co.ke/job/ict-intern-spear-the-science-for-africa-foundation', 'https://www.myjobmag.co.ke/job/ict-officer-i-tana-river-county', 'https://www.myjobmag.co.ke/job/software-engineer-data-infrastructure-opensearch-elastic-search-canonical-1', 'https://www.myjobmag.co.ke/job/senior-agile-program-manager-payment-methods-cellulant-corporation', 'https://www.myjobmag.co.ke/job/consultant-global-hiv-drug-resistance-hivdr-database-world-health-organization', 'https://www.myjobmag.co.ke/job/vas-support-engineer-safaricom-kenya', 'https://www.myjobmag.co.ke/job/senior-officer-cyber-security-assurance-safaricom-kenya-3']
# ['https://www.myjobmag.co.ke/job/information-technology-it-assistant-kakuzi-plc', 'https://www.myjobmag.co.ke/job/python-software-engineer-ubuntu-hardware-certification-team-canonical-3', 'https://www.myjobmag.co.ke/job/ict-intern-spear-the-science-for-africa-foundation', 'https://www.myjobmag.co.ke/job/ict-officer-i-tana-river-county', 'https://www.myjobmag.co.ke/job/software-engineer-data-infrastructure-opensearch-elastic-search-canonical-1', 'https://www.myjobmag.co.ke/job/senior-agile-program-manager-payment-methods-cellulant-corporation', 'https://www.myjobmag.co.ke/job/consultant-global-hiv-drug-resistance-hivdr-database-world-health-organization', 'https://www.myjobmag.co.ke/job/vas-support-engineer-safaricom-kenya', 'https://www.myjobmag.co.ke/job/senior-officer-cyber-security-assurance-safaricom-kenya-3', 'https://www.myjobmag.co.ke/job/senior-fms-developer-save-the-children']
# ['https://www.myjobmag.co.ke/job/information-technology-it-assistant-kakuzi-plc', 'https://www.myjobmag.co.ke/job/python-software-engineer-ubuntu-hardware-certification-team-canonical-3', 'https://www.myjobmag.co.ke/job/ict-intern-spear-the-science-for-africa-foundation', 'https://www.myjobmag.co.ke/job/ict-officer-i-tana-river-county', 'https://www.myjobmag.co.ke/job/software-engineer-data-infrastructure-opensearch-elastic-search-canonical-1', 'https://www.myjobmag.co.ke/job/senior-agile-program-manager-payment-methods-cellulant-corporation', 'https://www.myjobmag.co.ke/job/consultant-global-hiv-drug-resistance-hivdr-database-world-health-organization', 'https://www.myjobmag.co.ke/job/vas-support-engineer-safaricom-kenya', 'https://www.myjobmag.co.ke/job/senior-officer-cyber-security-assurance-safaricom-kenya-3', 'https://www.myjobmag.co.ke/job/senior-fms-developer-save-the-children', 'https://www.myjobmag.co.ke/job/head-it-platform-operations-ncba-group']
# ['https://www.myjobmag.co.ke/job/information-technology-it-assistant-kakuzi-plc', 'https://www.myjobmag.co.ke/job/python-software-engineer-ubuntu-hardware-certification-team-canonical-3', 'https://www.myjobmag.co.ke/job/ict-intern-spear-the-science-for-africa-foundation', 'https://www.myjobmag.co.ke/job/ict-officer-i-tana-river-county', 'https://www.myjobmag.co.ke/job/software-engineer-data-infrastructure-opensearch-elastic-search-canonical-1', 'https://www.myjobmag.co.ke/job/senior-agile-program-manager-payment-methods-cellulant-corporation', 'https://www.myjobmag.co.ke/job/consultant-global-hiv-drug-resistance-hivdr-database-world-health-organization', 'https://www.myjobmag.co.ke/job/vas-support-engineer-safaricom-kenya', 'https://www.myjobmag.co.ke/job/senior-officer-cyber-security-assurance-safaricom-kenya-3', 'https://www.myjobmag.co.ke/job/senior-fms-developer-save-the-children', 'https://www.myjobmag.co.ke/job/head-it-platform-operations-ncba-group', 'https://www.myjobmag.co.ke/job/project-officer-humanitarian-information-and-reporting-world-vision-kenya']
# ['https://www.myjobmag.co.ke/job/information-technology-it-assistant-kakuzi-plc', 'https://www.myjobmag.co.ke/job/python-software-engineer-ubuntu-hardware-certification-team-canonical-3', 'https://www.myjobmag.co.ke/job/ict-intern-spear-the-science-for-africa-foundation', 'https://www.myjobmag.co.ke/job/ict-officer-i-tana-river-county', 'https://www.myjobmag.co.ke/job/software-engineer-data-infrastructure-opensearch-elastic-search-canonical-1', 'https://www.myjobmag.co.ke/job/senior-agile-program-manager-payment-methods-cellulant-corporation', 'https://www.myjobmag.co.ke/job/consultant-global-hiv-drug-resistance-hivdr-database-world-health-organization', 'https://www.myjobmag.co.ke/job/vas-support-engineer-safaricom-kenya', 'https://www.myjobmag.co.ke/job/senior-officer-cyber-security-assurance-safaricom-kenya-3', 'https://www.myjobmag.co.ke/job/senior-fms-developer-save-the-children', 'https://www.myjobmag.co.ke/job/head-it-platform-operations-ncba-group', 'https://www.myjobmag.co.ke/job/project-officer-humanitarian-information-and-reporting-world-vision-kenya', 'https://www.myjobmag.co.ke/job/it-support-officer-medecins-sans-frontieres-msf']
# ['https://www.myjobmag.co.ke/job/information-technology-it-assistant-kakuzi-plc', 'https://www.myjobmag.co.ke/job/python-software-engineer-ubuntu-hardware-certification-team-canonical-3', 'https://www.myjobmag.co.ke/job/ict-intern-spear-the-science-for-africa-foundation', 'https://www.myjobmag.co.ke/job/ict-officer-i-tana-river-county', 'https://www.myjobmag.co.ke/job/software-engineer-data-infrastructure-opensearch-elastic-search-canonical-1', 'https://www.myjobmag.co.ke/job/senior-agile-program-manager-payment-methods-cellulant-corporation', 'https://www.myjobmag.co.ke/job/consultant-global-hiv-drug-resistance-hivdr-database-world-health-organization', 'https://www.myjobmag.co.ke/job/vas-support-engineer-safaricom-kenya', 'https://www.myjobmag.co.ke/job/senior-officer-cyber-security-assurance-safaricom-kenya-3', 'https://www.myjobmag.co.ke/job/senior-fms-developer-save-the-children', 'https://www.myjobmag.co.ke/job/head-it-platform-operations-ncba-group', 'https://www.myjobmag.co.ke/job/project-officer-humanitarian-information-and-reporting-world-vision-kenya', 'https://www.myjobmag.co.ke/job/it-support-officer-medecins-sans-frontieres-msf', 'https://www.myjobmag.co.ke/job/it-officer-system-aaa-growers']
# ['https://www.myjobmag.co.ke/job/information-technology-it-assistant-kakuzi-plc', 'https://www.myjobmag.co.ke/job/python-software-engineer-ubuntu-hardware-certification-team-canonical-3', 'https://www.myjobmag.co.ke/job/ict-intern-spear-the-science-for-africa-foundation', 'https://www.myjobmag.co.ke/job/ict-officer-i-tana-river-county', 'https://www.myjobmag.co.ke/job/software-engineer-data-infrastructure-opensearch-elastic-search-canonical-1', 'https://www.myjobmag.co.ke/job/senior-agile-program-manager-payment-methods-cellulant-corporation', 'https://www.myjobmag.co.ke/job/consultant-global-hiv-drug-resistance-hivdr-database-world-health-organization', 'https://www.myjobmag.co.ke/job/vas-support-engineer-safaricom-kenya', 'https://www.myjobmag.co.ke/job/senior-officer-cyber-security-assurance-safaricom-kenya-3', 'https://www.myjobmag.co.ke/job/senior-fms-developer-save-the-children', 'https://www.myjobmag.co.ke/job/head-it-platform-operations-ncba-group', 'https://www.myjobmag.co.ke/job/project-officer-humanitarian-information-and-reporting-world-vision-kenya', 'https://www.myjobmag.co.ke/job/it-support-officer-medecins-sans-frontieres-msf', 'https://www.myjobmag.co.ke/job/it-officer-system-aaa-growers', 'https://www.myjobmag.co.ke/job/assistant-manager-card-management-systems-i-m-bank']
# ['https://www.myjobmag.co.ke/job/information-technology-it-assistant-kakuzi-plc', 'https://www.myjobmag.co.ke/job/python-software-engineer-ubuntu-hardware-certification-team-canonical-3', 'https://www.myjobmag.co.ke/job/ict-intern-spear-the-science-for-africa-foundation', 'https://www.myjobmag.co.ke/job/ict-officer-i-tana-river-county', 'https://www.myjobmag.co.ke/job/software-engineer-data-infrastructure-opensearch-elastic-search-canonical-1', 'https://www.myjobmag.co.ke/job/senior-agile-program-manager-payment-methods-cellulant-corporation', 'https://www.myjobmag.co.ke/job/consultant-global-hiv-drug-resistance-hivdr-database-world-health-organization', 'https://www.myjobmag.co.ke/job/vas-support-engineer-safaricom-kenya', 'https://www.myjobmag.co.ke/job/senior-officer-cyber-security-assurance-safaricom-kenya-3', 'https://www.myjobmag.co.ke/job/senior-fms-developer-save-the-children', 'https://www.myjobmag.co.ke/job/head-it-platform-operations-ncba-group', 'https://www.myjobmag.co.ke/job/project-officer-humanitarian-information-and-reporting-world-vision-kenya', 'https://www.myjobmag.co.ke/job/it-support-officer-medecins-sans-frontieres-msf', 'https://www.myjobmag.co.ke/job/it-officer-system-aaa-growers', 'https://www.myjobmag.co.ke/job/assistant-manager-card-management-systems-i-m-bank', 'https://www.myjobmag.co.ke/job/sap-fico-analyst-madison-group-limited']
# ['https://www.myjobmag.co.ke/job/information-technology-it-assistant-kakuzi-plc', 'https://www.myjobmag.co.ke/job/python-software-engineer-ubuntu-hardware-certification-team-canonical-3', 'https://www.myjobmag.co.ke/job/ict-intern-spear-the-science-for-africa-foundation', 'https://www.myjobmag.co.ke/job/ict-officer-i-tana-river-county', 'https://www.myjobmag.co.ke/job/software-engineer-data-infrastructure-opensearch-elastic-search-canonical-1', 'https://www.myjobmag.co.ke/job/senior-agile-program-manager-payment-methods-cellulant-corporation', 'https://www.myjobmag.co.ke/job/consultant-global-hiv-drug-resistance-hivdr-database-world-health-organization', 'https://www.myjobmag.co.ke/job/vas-support-engineer-safaricom-kenya', 'https://www.myjobmag.co.ke/job/senior-officer-cyber-security-assurance-safaricom-kenya-3', 'https://www.myjobmag.co.ke/job/senior-fms-developer-save-the-children', 'https://www.myjobmag.co.ke/job/head-it-platform-operations-ncba-group', 'https://www.myjobmag.co.ke/job/project-officer-humanitarian-information-and-reporting-world-vision-kenya', 'https://www.myjobmag.co.ke/job/it-support-officer-medecins-sans-frontieres-msf', 'https://www.myjobmag.co.ke/job/it-officer-system-aaa-growers', 'https://www.myjobmag.co.ke/job/assistant-manager-card-management-systems-i-m-bank', 'https://www.myjobmag.co.ke/job/sap-fico-analyst-madison-group-limited', 'https://www.myjobmag.co.ke/job/volunteer-website-content-audit-for-alamos-ict-solutions-catchafire']
# ['https://www.myjobmag.co.ke/job/information-technology-it-assistant-kakuzi-plc', 'https://www.myjobmag.co.ke/job/python-software-engineer-ubuntu-hardware-certification-team-canonical-3', 'https://www.myjobmag.co.ke/job/ict-intern-spear-the-science-for-africa-foundation', 'https://www.myjobmag.co.ke/job/ict-officer-i-tana-river-county', 'https://www.myjobmag.co.ke/job/software-engineer-data-infrastructure-opensearch-elastic-search-canonical-1', 'https://www.myjobmag.co.ke/job/senior-agile-program-manager-payment-methods-cellulant-corporation', 'https://www.myjobmag.co.ke/job/consultant-global-hiv-drug-resistance-hivdr-database-world-health-organization', 'https://www.myjobmag.co.ke/job/vas-support-engineer-safaricom-kenya', 'https://www.myjobmag.co.ke/job/senior-officer-cyber-security-assurance-safaricom-kenya-3', 'https://www.myjobmag.co.ke/job/senior-fms-developer-save-the-children', 'https://www.myjobmag.co.ke/job/head-it-platform-operations-ncba-group', 'https://www.myjobmag.co.ke/job/project-officer-humanitarian-information-and-reporting-world-vision-kenya', 'https://www.myjobmag.co.ke/job/it-support-officer-medecins-sans-frontieres-msf', 'https://www.myjobmag.co.ke/job/it-officer-system-aaa-growers', 'https://www.myjobmag.co.ke/job/assistant-manager-card-management-systems-i-m-bank', 'https://www.myjobmag.co.ke/job/sap-fico-analyst-madison-group-limited', 'https://www.myjobmag.co.ke/job/volunteer-website-content-audit-for-alamos-ict-solutions-catchafire', 'https://www.myjobmag.co.ke/job/volunteer-infographic-for-alamos-ict-solutions-catchafire']
# ['Web Designer and Developer', 'Sales Executive', 'Developer ServiceNow (ITSM)', 'Remote SEO Specialist', 'Talent Scout', 'Business Consultant', 'ANGULAR Developer (M/F)', 'DevOps Engineer (M/F)', 'DOTNET Developer (M/F)', 'IOS Developer (M/F)', 'JAVA Developer (M/F)', 'JAVA JEE Developer (M/F)', 'JAVASCRIPT Developer (M/F)', 'KOTLIN Developer (M/F)', 'LARAVEL Developer (M/F)', 'NODE.JS Developer (M/F)', 'OBJECTIVE-C Developer (M/F)', 'PHP Developer (M/F)', 'PYTHON Developer (M/F)', 'QA Tester (M/F)', 'REACT Developer (M/F)', 'RUBY ON RAILS Developer (M/F)', 'SWIFT Developer (M/F)', 'Test and Validation Engineer (M/F)', 'Test Automation Engineer (M/F)']

# %% [markdown]
# ## <font color='#2F4F4F'>Step 4: Saving our Data</font>

# %%
# Saving the scraped contents in a dataframe and preview our data
# ---
#
# Saving the scraped contents in a dataframe and preview our data
# ---
#pigiame dataframe
df_pigiame = pd.DataFrame({"Title": pigia_me_link_title , "Link": pigia_me_link_url})
df_pigiame.head()

#pigiame dataframe
df_myjob = pd.DataFrame({"Title":  myjob_link_title , "Link": myjob_link_url})


#pigiame dataframe
df_kenyajob = pd.DataFrame({"Title":kenyajob_link_title , "Link": kenyajob_link_url})
# concatenate the tables
df_job_search = pd.concat([df_pigiame, df_myjob,df_kenyajob], axis=0)

df_job_search
# Out:
#                                                 Title  \
# 0                             VP, Data at Flutterwave
# 1                          Process Engineer at DryGro
# 2   Analyst,MLU 3 at Church of Jesus Christ of Lat...
# 3   MEAN Stack Developer-MongoDB, AngularJS, and N...
# 4                         Process Analyst at I&M Bank
# 5            ICT Support Technician at KCA University
# 6   Director, Data Products, Community Pass at Mas...
# 7                          Market Development Analyst
# 8                                IT Officer - Systems
# 9                                    Engineering Lead
# 0   Information Technology (IT) Assistant at Kakuz...
# 1   Python Software Engineer - Ubuntu Hardware Cer...
# 2   ICT Intern -SPEAR at The Science for Africa Fo...
# 3                  ICT Officer I at Tana River County
# 4   Software Engineer - Data Infrastructure - Open...
# 5   Senior Agile Program Manager (Payment Methods)...
# 6   Consultant – Global HIV Drug Resistance (HIVDR...
# 7             VAS Support Engineer at Safaricom Kenya
# 8   Senior Officer, Cyber Security Assurance at Sa...
# 9           Senior FMS Developer at Save the Children
# 10         Head, IT Platform Operations at NCBA Group
# 11  Project Officer- Humanitarian Information and ...
# 12  IT Support Officer at Medecins Sans Frontieres...
# 13                 IT Officer - System at AAA Growers
# 14  Assistant Manager, Card Management Systems at ...
# 15          SAP FICO Analyst at Madison Group Limited
# 16  Volunteer: Website Content Audit for Alamos IC...
# 17  Volunteer: Infographic for Alamos ICT Solution...
# 0                          Web Designer and Developer
# 1                                     Sales Executive
# 2                         Developer ServiceNow (ITSM)
# 3                               Remote SEO Specialist
# 4                                        Talent Scout
# 5                                 Business Consultant
# 6                             ANGULAR Developer (M/F)
# 7                               DevOps Engineer (M/F)
# 8                              DOTNET Developer (M/F)
# 9                                 IOS Developer (M/F)
# 10                               JAVA Developer (M/F)
# 11                           JAVA JEE Developer (M/F)
# 12                         JAVASCRIPT Developer (M/F)
# 13                             KOTLIN Developer (M/F)
# 14                            LARAVEL Developer (M/F)
# 15                            NODE.JS Developer (M/F)
# 16                        OBJECTIVE-C Developer (M/F)
# 17                                PHP Developer (M/F)
# 18                             PYTHON Developer (M/F)
# 19                                    QA Tester (M/F)
# 20                              REACT Developer (M/F)
# 21                      RUBY ON RAILS Developer (M/F)
# 22                              SWIFT Developer (M/F)
# 23                 Test and Validation Engineer (M/F)
# 24                     Test Automation Engineer (M/F)
#
#                                                  Link
# 0   https://www.pigiame.co.ke/listings/vp-data-at-...
# 1   https://www.pigiame.co.ke/listings/process-eng...
# 2   https://www.pigiame.co.ke/listings/analystmlu-...
# 3   https://www.pigiame.co.ke/listings/mean-stack-...
# 4   https://www.pigiame.co.ke/listings/process-ana...
# 5   https://www.pigiame.co.ke/listings/ict-support...
# 6   https://www.pigiame.co.ke/listings/director-da...
# 7   https://www.pigiame.co.ke/listings/market-deve...
# 8   https://www.pigiame.co.ke/listings/it-officer-...
# 9   https://www.pigiame.co.ke/listings/engineering...
# 0   https://www.myjobmag.co.ke/job/information-tec...
# 1   https://www.myjobmag.co.ke/job/python-software...
# 2   https://www.myjobmag.co.ke/job/ict-intern-spea...
# 3   https://www.myjobmag.co.ke/job/ict-officer-i-t...
# 4   https://www.myjobmag.co.ke/job/software-engine...
# 5   https://www.myjobmag.co.ke/job/senior-agile-pr...
# 6   https://www.myjobmag.co.ke/job/consultant-glob...
# 7   https://www.myjobmag.co.ke/job/vas-support-eng...
# 8   https://www.myjobmag.co.ke/job/senior-officer-...
# 9   https://www.myjobmag.co.ke/job/senior-fms-deve...
# 10  https://www.myjobmag.co.ke/job/head-it-platfor...
# 11  https://www.myjobmag.co.ke/job/project-officer...
# 12  https://www.myjobmag.co.ke/job/it-support-offi...
# 13  https://www.myjobmag.co.ke/job/it-officer-syst...
# 14  https://www.myjobmag.co.ke/job/assistant-manag...
# 15  https://www.myjobmag.co.ke/job/sap-fico-analys...
# 16  https://www.myjobmag.co.ke/job/volunteer-websi...
# 17  https://www.myjobmag.co.ke/job/volunteer-infog...
# 0   https://www.kenyajob.com/job-vacancies-kenya/w...
# 1   https://www.kenyajob.com/job-vacancies-kenya/s...
# 2   https://www.kenyajob.com/job-vacancies-kenya/d...
# 3   https://www.kenyajob.com/job-vacancies-kenya/r...
# 4   https://www.kenyajob.com/job-vacancies-kenya/t...
# 5   https://www.kenyajob.com/job-vacancies-kenya/b...
# 6   https://www.kenyajob.com/job-vacancies-kenya/a...
# 7   https://www.kenyajob.com/job-vacancies-kenya/d...
# 8   https://www.kenyajob.com/job-vacancies-kenya/d...
# 9   https://www.kenyajob.com/job-vacancies-kenya/i...
# 10  https://www.kenyajob.com/job-vacancies-kenya/j...
# 11  https://www.kenyajob.com/job-vacancies-kenya/j...
# 12  https://www.kenyajob.com/job-vacancies-kenya/j...
# 13  https://www.kenyajob.com/job-vacancies-kenya/k...
# 14  https://www.kenyajob.com/job-vacancies-kenya/l...
# 15  https://www.kenyajob.com/job-vacancies-kenya/n...
# 16  https://www.kenyajob.com/job-vacancies-kenya/o...
# 17  https://www.kenyajob.com/job-vacancies-kenya/p...
# 18  https://www.kenyajob.com/job-vacancies-kenya/p...
# 19  https://www.kenyajob.com/job-vacancies-kenya/q...
# 20  https://www.kenyajob.com/job-vacancies-kenya/r...
# 21  https://www.kenyajob.com/job-vacancies-kenya/r...
# 22  https://www.kenyajob.com/job-vacancies-kenya/s...
# 23  https://www.kenyajob.com/job-vacancies-kenya/t...
# 24  https://www.kenyajob.com/job-vacancies-kenya/t...
